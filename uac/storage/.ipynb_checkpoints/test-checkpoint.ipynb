# %%
import pandas as pd

# %%
df = pd.read_csv('/home/v1nh/v1nh/chatbot/uac/storage/data.csv')

df
# Out:
#   Cell In[2], line 1
#     df = pd.read_csv('/home/v1nh/v1nh/chatbot/uac/storage/data.csv)
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df.drop_duplicates(inplace=True)

df
# Out:
#                                                  Title  \
# 0              CÁC NGÀNH ĐÀO TẠO CỦA ĐẠI HỌC BÁCH KHOA
# 1               các tổ hợp xét tuyển gồm những môn nào
# 2                                    các ngành đào tạo
# 3                          Mã ngành Công nghệ sinh học
# 4                   Mã ngành Công nghệ sinh học Y Dược
# ..                                                 ...
# 574  Em muốn ĐKXT vào ngành Giáo dục Mầm non, vậy e...
# 575  Em có thể đăng 2 nguyện vọng tại 1 trường vào ...
# 576  Em muốn hỏi khi em đã trúng tuyển ở đợt xét tu...
# 577  Em có chứng chỉ tiếng Anh quốc tế IELTS, Toefl...
# 578  Em muốn đăng ký xét tuyển học bạ vào ngành có ...
#
#                                                   Text
# 0    các ngành đạo Đại học bao gồm:\n7420201: Công ...
# 1    A00: Toán, Lý, Hóa\nA01: Toán, Lý, Anh\nB00: T...
# 2    Công nghệ sinh học\nCông nghệ sinh học Y Dược\...
# 3                                              7420201
# ...

# %%
from pymilvus_orm.lite import MilvusLite
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from pymilvus_orm.lite import MilvusLite
#
# ModuleNotFoundError: No module named 'pymilvus_orm'

# %%
from pymilvus import MilvusLite

# Khởi động Milvus Lite
milvus = MilvusLite()
milvus.start()

print("Milvus Lite đã khởi động thành công!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from pymilvus import MilvusLite
#       3 # Khởi động Milvus Lite
#       4 milvus = MilvusLite()
#
# ImportError: cannot import name 'MilvusLite' from 'pymilvus' (/home/v1nh/v1nh/chatbot/venv/lib/python3.12/site-packages/pymilvus/__init__.py)
